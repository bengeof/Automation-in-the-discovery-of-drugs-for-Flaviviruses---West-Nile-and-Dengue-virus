# %% [markdown]
# # Data Mining From PubChem

# %%
import pandas as pd
import numpy as np
import urllib
import os 
import requests
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
get_ipython().magic(u'matplotlib inline')
import time

# %%
link1 = "https://pubchem.ncbi.nlm.nih.gov/sdq/cgi2rcgi.cgi?infmt=json&outfmt=csv&query={%22download%22:%22*%22,%22collection%22:%22bioactivity%22,%22where%22:{%22ands%22:[{%22protacxn%22:%22notnull%22},{%22cid%22:%22notnull%22},{%22repacxn%22:%22P06935%22}]},%22order%22:[%22acvalue,asc%22],%22start%22:1,%22limit%22:10000000,%22downloadfilename%22:%22PROTACXN_P06935_bioactivity_protein%22}"

# %%
for i in range(0,2):
    try:
        os.remove('downloaded1.csv')
        #print("Deleted old File")
        break
    except Exception as e:
        #print("No file ")
        break
    else:
        break

# %%
for i in range(2):
    try:
        req = requests.get(link1)
        url_content = req.content
        csv_file = open('downloaded1.csv', 'wb')
        csv_file.write(url_content)
        csv_file.close()
        print("Completed the Request")
        break
    #except IncompleteRead as I:
     #   print("Server Overloading , Proceeding")
      #  break
    except Exception as a:
        print(str(a)+" is the error , Trying {} time".format(i))
        continue
    else:
        break
else:
    print("something Wrong , Try running Again [refer error code for more]")
# Out:
# Completed the Request

# %%
data = pd.read_csv("downloaded1.csv",error_bad_lines=False)

data_df = pd.DataFrame(data)

new_data = data[['cid','acvalue']]


new_data = new_data.dropna()

# %%
#n_val=30
except_val=0

# %%
cid_value = new_data['cid'].to_list()

PIC50_value = (-np.log10(new_data['acvalue']*10**-6)).to_list()

# %%
PIC50_value = pd.DataFrame(PIC50_value,columns = ["y"])

# %%
y_data = PIC50_value

# %%
#len(y_data)

# %%
link = "https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/new_link_me/property/MolecularWeight,HeavyAtomCount,XLOGP,Complexity,HBondAcceptorCount,MonoisotopicMass,RotatableBondCount,TPSA/CSV"
link_fixed = "https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/new_link_me/property/MolecularWeight,HeavyAtomCount,XLOGP,Complexity,HBondAcceptorCount,MonoisotopicMass,RotatableBondCount,TPSA/CSV"
sub_link = "https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/fastsimilarity_2d/cid/replaceme/cids/TXT"
sub_link_fixed = "https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/fastsimilarity_2d/cid/replaceme/cids/TXT"
#the link with the required properties.
counter = 1

# %%
final_data_frame = pd.DataFrame()

# creating empty dataframe for attaching !

#final_data_frame

# %%
x_data = pd.DataFrame()


cid_main_counter=0

# %%
for x in cid_value:
    for iter_x in range(1000):
        try:    
            link = link_fixed
            link = link.replace("new_link_me",str(x))
            data1 = pd.read_csv(link)
            data1 = pd.DataFrame(data1)
            x_data = x_data.append(data1)
            data1 = 0
        except Exception as e:
            print("Exception Encountered as {} .! , Trying again !Iteration : {}".format(str(e),str(iter_x)))
            time.sleep(5)
            continue
        else:
            break
    
    else:
        print("Something Wrong with the Trials ! Restart The Algorithm!")

# %%
x_data_saved = x_data

# %%
x_data = x_data_saved

# %%
#x_data

# %%
n_cid=[]

# %%
#20 sec Wait_time
for i in cid_value:
    max_tries = 10
    
    for iter_ in range(max_tries):
        try:
            #print("inside Try")
            #time.sleep(5)


            link = link_fixed
            link = link.replace("new_link_me",str(i))
            f_data = pd.read_csv(link) 
            
            sub_link = sub_link_fixed
            sub_link = sub_link.replace("replaceme",str(i))
            res = urllib.request.urlopen(sub_link)
            data_sub = res.read()
            data_sub = str(data_sub)
            data_sub = data_sub.replace("\\n",",") ; data_sub = data_sub.replace('b'," ")
            data_sub = data_sub.replace("'",""); data_sub = data_sub.replace(" ","")
            n_count_loop = 0 
            #time.sleep(3)
            #print("Going for the loop")
            for j in data_sub.split(","):
                n_count_loop+=1
                if(len(j)>1):
                    if(n_count_loop<=30):
                        n_cid.append(j)
                    else:
                        break
                else:
                    pass
             
        except:
            if(except_val>=15):
                break
            else:
                print("Re-Trying")
                except_val+=1
                #time.sleep(3)
                continue
        else:
            break
    '''else:
        print("Either The Network is Down(So no point in continuing ) , Or Some Uknown Error Spotted!. Refer Error Code , Continuing with Fetched Data")
        time.sleep(5)
        break'''
    
    
    '''final_data_frame = final_data_frame.append(f_data)
    cid_main_counter+=1
    final_data_frame.to_csv("fdf1.csv")
         
   

    print("Main cid no: {}".format(cid_main_counter))
    #time.sleep(5)'''

# %%
#len(n_cid)

# %%
k_count = 0
t_count = 0
phase_count=0

# %%
#n_cid_list = [44511706,25256828,44511706,25256828]
f_data = pd.DataFrame()


#replace

# %%
for k in n_cid:
    k_count+=1
    t_count+=1
    phase_count+=1
    for sub_iter in range(10):
            try:
                if(t_count>=50):
                    #print("taking Rest")
                    time.sleep(15)
                    t_count=0
                    
                #print("Inside Try"+str(k_count))
            
                link = link_fixed
                link = link.replace("new_link_me",str(k))
                #print("replacement done"+str(k_count))
                f_data_df = pd.read_csv(link)
                f_data = f_data.append(f_data_df)
                print("Passed Without Exception"+str(k_count))
                break

            except Exception as e:
                print(str(e) + "Encountered , Please Wait :+ "+str(k_count))
                time.sleep(20)
                continue

    final_data_frame = final_data_frame.append(f_data)
    cid_main_counter+=1
    final_data_frame.to_csv("fdf1.csv")
    print("Data Fetching Continued"+ str(k_count))
    
    final_data_frame.drop_duplicates(inplace=True)
# Out:
# Passed Without Exception1
# Data Fetching Continued1
# Passed Without Exception2
# Data Fetching Continued2
# Passed Without Exception3
# Data Fetching Continued3
# Passed Without Exception4
# Data Fetching Continued4
# Passed Without Exception5
# Data Fetching Continued5
# Passed Without Exception6
# Data Fetching Continued6
# Passed Without Exception7
# Data Fetching Continued7
# Passed Without Exception8
# Data Fetching Continued8
# Passed Without Exception9
# Data Fetching Continued9
# Passed Without Exception10
# Data Fetching Continued10
# Passed Without Exception11
# Data Fetching Continued11
# Passed Without Exception12
# Data Fetching Continued12
# Passed Without Exception13
# Data Fetching Continued13
# Passed Without Exception14
# Data Fetching Continued14
# Passed Without Exception15
# Data Fetching Continued15
# Passed Without Exception16
# Data Fetching Continued16
# Passed Without Exception17
# Data Fetching Continued17
# Passed Without Exception18
# Data Fetching Continued18
# Passed Without Exception19
# Data Fetching Continued19
# Passed Without Exception20
# Data Fetching Continued20
# Passed Without Exception21
# Data Fetching Continued21
# Passed Without Exception22
# Data Fetching Continued22
# Passed Without Exception23
# Data Fetching Continued23
# Passed Without Exception24
# Data Fetching Continued24
# Passed Without Exception25
# Data Fetching Continued25
# Passed Without Exception26
# Data Fetching Continued26
# Passed Without Exception27
# Data Fetching Continued27
# Passed Without Exception28
# Data Fetching Continued28
# Passed Without Exception29
# Data Fetching Continued29
# Passed Without Exception30
# Data Fetching Continued30
# Passed Without Exception31
# Data Fetching Continued31
# Passed Without Exception32
# Data Fetching Continued32
# Passed Without Exception33
# Data Fetching Continued33
# Passed Without Exception34
# Data Fetching Continued34
# Passed Without Exception35
# Data Fetching Continued35
# Passed Without Exception36
# Data Fetching Continued36
# Passed Without Exception37
# Data Fetching Continued37
# Passed Without Exception38
# Data Fetching Continued38
# Passed Without Exception39
# Data Fetching Continued39
# Passed Without Exception40
# Data Fetching Continued40
# Passed Without Exception41
# Data Fetching Continued41
# Passed Without Exception42
# Data Fetching Continued42
# Passed Without Exception43
# Data Fetching Continued43
# Passed Without Exception44
# Data Fetching Continued44
# Passed Without Exception45
# Data Fetching Continued45
# Passed Without Exception46
# Data Fetching Continued46
# Passed Without Exception47
# Data Fetching Continued47
# Passed Without Exception48
# Data Fetching Continued48
# Passed Without Exception49
# Data Fetching Continued49
# Passed Without Exception50
# Data Fetching Continued50
# Passed Without Exception51
# Data Fetching Continued51
# Passed Without Exception52
# Data Fetching Continued52
# Passed Without Exception53
# Data Fetching Continued53
# Passed Without Exception54
# Data Fetching Continued54
# Passed Without Exception55
# Data Fetching Continued55
# Passed Without Exception56
# Data Fetching Continued56
# Passed Without Exception57
# Data Fetching Continued57
# Passed Without Exception58
# Data Fetching Continued58
# Passed Without Exception59
# Data Fetching Continued59
# Passed Without Exception60
# Data Fetching Continued60
# Passed Without Exception61
# Data Fetching Continued61
# Passed Without Exception62
# Data Fetching Continued62
# Passed Without Exception63
# Data Fetching Continued63
# Passed Without Exception64
# Data Fetching Continued64
# Passed Without Exception65
# Data Fetching Continued65
# Passed Without Exception66
# Data Fetching Continued66
# Passed Without Exception67
# Data Fetching Continued67
# Passed Without Exception68
# Data Fetching Continued68
# Passed Without Exception69
# Data Fetching Continued69
# Passed Without Exception70
# Data Fetching Continued70
# Passed Without Exception71
# Data Fetching Continued71
# Passed Without Exception72
# Data Fetching Continued72
# Passed Without Exception73
# Data Fetching Continued73
# Passed Without Exception74
# Data Fetching Continued74
# Passed Without Exception75
# Data Fetching Continued75
# Passed Without Exception76
# Data Fetching Continued76
# Passed Without Exception77
# Data Fetching Continued77
# Passed Without Exception78
# Data Fetching Continued78
# Passed Without Exception79
# Data Fetching Continued79
# Passed Without Exception80
# Data Fetching Continued80
# Passed Without Exception81
# Data Fetching Continued81
# Passed Without Exception82
# Data Fetching Continued82
# Passed Without Exception83
# Data Fetching Continued83
# Passed Without Exception84
# Data Fetching Continued84
# Passed Without Exception85
# Data Fetching Continued85
# Passed Without Exception86
# Data Fetching Continued86
# Passed Without Exception87
# Data Fetching Continued87
# Passed Without Exception88
# Data Fetching Continued88
# Passed Without Exception89
# Data Fetching Continued89
# Passed Without Exception90
# Data Fetching Continued90
# Passed Without Exception91
# Data Fetching Continued91
# Passed Without Exception92
# Data Fetching Continued92
# Passed Without Exception93
# Data Fetching Continued93
# Passed Without Exception94
# Data Fetching Continued94
# Passed Without Exception95
# Data Fetching Continued95
# Passed Without Exception96
# Data Fetching Continued96
# Passed Without Exception97
# Data Fetching Continued97
# Passed Without Exception98
# Data Fetching Continued98
# Passed Without Exception99
# Data Fetching Continued99
# Passed Without Exception100
# Data Fetching Continued100
# Passed Without Exception101
# Data Fetching Continued101
# Passed Without Exception102
# Data Fetching Continued102
# Passed Without Exception103
# Data Fetching Continued103
# Passed Without Exception104
# Data Fetching Continued104
# Passed Without Exception105
# Data Fetching Continued105
# Passed Without Exception106
# Data Fetching Continued106
# Passed Without Exception107
# Data Fetching Continued107
# Passed Without Exception108
# Data Fetching Continued108
# Passed Without Exception109
# Data Fetching Continued109
# Passed Without Exception110
# Data Fetching Continued110
# Passed Without Exception111
# Data Fetching Continued111
# Passed Without Exception112
# Data Fetching Continued112
# Passed Without Exception113
# Data Fetching Continued113
# Passed Without Exception114
# Data Fetching Continued114
# Passed Without Exception115
# Data Fetching Continued115
# Passed Without Exception116
# Data Fetching Continued116
# Passed Without Exception117
# Data Fetching Continued117
# Passed Without Exception118
# Data Fetching Continued118
# Passed Without Exception119
# Data Fetching Continued119
# Passed Without Exception120
# Data Fetching Continued120
# Passed Without Exception121
# Data Fetching Continued121
# Passed Without Exception122
# Data Fetching Continued122
# Passed Without Exception123
# Data Fetching Continued123
# Passed Without Exception124
# Data Fetching Continued124
# Passed Without Exception125
# Data Fetching Continued125
# Passed Without Exception126
# Data Fetching Continued126
# Passed Without Exception127
# Data Fetching Continued127
# Passed Without Exception128
# Data Fetching Continued128
# Passed Without Exception129
# Data Fetching Continued129
# Passed Without Exception130
# Data Fetching Continued130
# Passed Without Exception131
# Data Fetching Continued131
# Passed Without Exception132
# Data Fetching Continued132
# Passed Without Exception133
# Data Fetching Continued133
# Passed Without Exception134
# Data Fetching Continued134
# Passed Without Exception135
# Data Fetching Continued135
# Passed Without Exception136
# Data Fetching Continued136
# Passed Without Exception137
# Data Fetching Continued137
# Passed Without Exception138
# Data Fetching Continued138
# Passed Without Exception139
# Data Fetching Continued139
# Passed Without Exception140
# Data Fetching Continued140
# Passed Without Exception141
# Data Fetching Continued141
# Passed Without Exception142
# Data Fetching Continued142
# Passed Without Exception143
# Data Fetching Continued143
# Passed Without Exception144
# Data Fetching Continued144
# Passed Without Exception145
# Data Fetching Continued145
# Passed Without Exception146
# Data Fetching Continued146
# Passed Without Exception147
# Data Fetching Continued147
# Passed Without Exception148
# Data Fetching Continued148
# Passed Without Exception149
# Data Fetching Continued149
# Passed Without Exception150
# Data Fetching Continued150
# Passed Without Exception151
# Data Fetching Continued151
# Passed Without Exception152
# Data Fetching Continued152
# Passed Without Exception153
# Data Fetching Continued153
# Passed Without Exception154
# Data Fetching Continued154
# Passed Without Exception155
# Data Fetching Continued155
# Passed Without Exception156
# Data Fetching Continued156
# Passed Without Exception157
# Data Fetching Continued157
# Passed Without Exception158
# Data Fetching Continued158
# Passed Without Exception159
# Data Fetching Continued159
# Passed Without Exception160
# Data Fetching Continued160
# Passed Without Exception161
# Data Fetching Continued161
# Passed Without Exception162
# Data Fetching Continued162
# Passed Without Exception163
# Data Fetching Continued163
# Passed Without Exception164
# Data Fetching Continued164
# Passed Without Exception165
# Data Fetching Continued165
# Passed Without Exception166
# Data Fetching Continued166
# Passed Without Exception167
# Data Fetching Continued167
# Passed Without Exception168
# Data Fetching Continued168
# Passed Without Exception169
# Data Fetching Continued169
# Passed Without Exception170
# Data Fetching Continued170
# Passed Without Exception171
# Data Fetching Continued171
# Passed Without Exception172
# Data Fetching Continued172
# Passed Without Exception173
# Data Fetching Continued173
# Passed Without Exception174
# Data Fetching Continued174
# Passed Without Exception175
# Data Fetching Continued175
# Passed Without Exception176
# Data Fetching Continued176
# Passed Without Exception177
# Data Fetching Continued177
# Passed Without Exception178
# Data Fetching Continued178
# Passed Without Exception179
# Data Fetching Continued179
# Passed Without Exception180
# Data Fetching Continued180
# Passed Without Exception181
# Data Fetching Continued181
# Passed Without Exception182
# Data Fetching Continued182
# Passed Without Exception183
# Data Fetching Continued183
# Passed Without Exception184
# Data Fetching Continued184
# Passed Without Exception185
# Data Fetching Continued185
# Passed Without Exception186
# Data Fetching Continued186
# Passed Without Exception187
# Data Fetching Continued187
# Passed Without Exception188
# Data Fetching Continued188
# Passed Without Exception189
# Data Fetching Continued189
# Passed Without Exception190
# Data Fetching Continued190
# Passed Without Exception191
# Data Fetching Continued191
# Passed Without Exception192
# Data Fetching Continued192
# Passed Without Exception193
# Data Fetching Continued193
# Passed Without Exception194
# Data Fetching Continued194
# Passed Without Exception195
# Data Fetching Continued195
# Passed Without Exception196
# Data Fetching Continued196
# Passed Without Exception197
# Data Fetching Continued197
# Passed Without Exception198
# Data Fetching Continued198
# Passed Without Exception199
# Data Fetching Continued199
# Passed Without Exception200
# Data Fetching Continued200
# Passed Without Exception201
# Data Fetching Continued201
# Passed Without Exception202
# Data Fetching Continued202
# Passed Without Exception203
# Data Fetching Continued203
# Passed Without Exception204
# Data Fetching Continued204
# Passed Without Exception205
# Data Fetching Continued205
# Passed Without Exception206
# Data Fetching Continued206
# Passed Without Exception207
# Data Fetching Continued207
# Passed Without Exception208
# Data Fetching Continued208
# Passed Without Exception209
# Data Fetching Continued209
# Passed Without Exception210
# Data Fetching Continued210
# Passed Without Exception211
# Data Fetching Continued211
# Passed Without Exception212
# Data Fetching Continued212
# Passed Without Exception213
# Data Fetching Continued213
# Passed Without Exception214
# Data Fetching Continued214
# Passed Without Exception215
# Data Fetching Continued215
# Passed Without Exception216
# Data Fetching Continued216
# Passed Without Exception217
# Data Fetching Continued217
# Passed Without Exception218
# Data Fetching Continued218
# Passed Without Exception219
# Data Fetching Continued219
# Passed Without Exception220
# Data Fetching Continued220
# Passed Without Exception221
# Data Fetching Continued221
# Passed Without Exception222
# Data Fetching Continued222
# Passed Without Exception223
# Data Fetching Continued223
# Passed Without Exception224
# Data Fetching Continued224
# Passed Without Exception225
# Data Fetching Continued225
# Passed Without Exception226
# Data Fetching Continued226
# Passed Without Exception227
# Data Fetching Continued227
# Passed Without Exception228
# Data Fetching Continued228
# Passed Without Exception229
# Data Fetching Continued229
# Passed Without Exception230
# Data Fetching Continued230
# Passed Without Exception231
# Data Fetching Continued231
# Passed Without Exception232
# Data Fetching Continued232
# Passed Without Exception233
# Data Fetching Continued233
# Passed Without Exception234
# Data Fetching Continued234
# Passed Without Exception235
# Data Fetching Continued235
# Passed Without Exception236
# Data Fetching Continued236
# Passed Without Exception237
# Data Fetching Continued237
# Passed Without Exception238
# Data Fetching Continued238
# Passed Without Exception239
# Data Fetching Continued239
# Passed Without Exception240
# Data Fetching Continued240
# Passed Without Exception241
# Data Fetching Continued241
# Passed Without Exception242
# Data Fetching Continued242
# Passed Without Exception243
# Data Fetching Continued243
# Passed Without Exception244
# Data Fetching Continued244
# Passed Without Exception245
# Data Fetching Continued245
# Passed Without Exception246
# Data Fetching Continued246
# Passed Without Exception247
# Data Fetching Continued247
# Passed Without Exception248
# Data Fetching Continued248
# Passed Without Exception249
# Data Fetching Continued249
# Passed Without Exception250
# Data Fetching Continued250
# Passed Without Exception251
# Data Fetching Continued251
# Passed Without Exception252
# Data Fetching Continued252
# Passed Without Exception253
# Data Fetching Continued253
# Passed Without Exception254
# Data Fetching Continued254
# Passed Without Exception255
# Data Fetching Continued255
# Passed Without Exception256
# Data Fetching Continued256
# Passed Without Exception257
# Data Fetching Continued257
# Passed Without Exception258
# Data Fetching Continued258
# Passed Without Exception259
# Data Fetching Continued259
# Passed Without Exception260
# Data Fetching Continued260
# Passed Without Exception261
# Data Fetching Continued261
# Passed Without Exception262
# Data Fetching Continued262
# Passed Without Exception263
# Data Fetching Continued263
# Passed Without Exception264
# Data Fetching Continued264
# Passed Without Exception265
# Data Fetching Continued265
# Passed Without Exception266
# Data Fetching Continued266
# Passed Without Exception267
# Data Fetching Continued267
# Passed Without Exception268
# Data Fetching Continued268
# Passed Without Exception269
# Data Fetching Continued269
# Passed Without Exception270
# Data Fetching Continued270
# Passed Without Exception271
# Data Fetching Continued271
# Passed Without Exception272
# Data Fetching Continued272
# Passed Without Exception273
# Data Fetching Continued273
# Passed Without Exception274
# Data Fetching Continued274
# Passed Without Exception275
# Data Fetching Continued275
# Passed Without Exception276
# Data Fetching Continued276
# Passed Without Exception277
# Data Fetching Continued277
# Passed Without Exception278
# Data Fetching Continued278
# Passed Without Exception279
# Data Fetching Continued279
# Passed Without Exception280
# Data Fetching Continued280
# Passed Without Exception281
# Data Fetching Continued281
# Passed Without Exception282
# Data Fetching Continued282
# Passed Without Exception283
# Data Fetching Continued283
# Passed Without Exception284
# Data Fetching Continued284
# Passed Without Exception285
# Data Fetching Continued285
# Passed Without Exception286
# Data Fetching Continued286
# Passed Without Exception287
# Data Fetching Continued287
# Passed Without Exception288
# Data Fetching Continued288
# Passed Without Exception289
# Data Fetching Continued289
# Passed Without Exception290
# Data Fetching Continued290
# Passed Without Exception291
# Data Fetching Continued291
# Passed Without Exception292
# Data Fetching Continued292
# Passed Without Exception293
# Data Fetching Continued293
# Passed Without Exception294
# Data Fetching Continued294
# Passed Without Exception295
# Data Fetching Continued295
# Passed Without Exception296
# Data Fetching Continued296
# Passed Without Exception297
# Data Fetching Continued297
# Passed Without Exception298
# Data Fetching Continued298
# Passed Without Exception299
# Data Fetching Continued299
# Passed Without Exception300
# Data Fetching Continued300
# Passed Without Exception301
# Data Fetching Continued301
# Passed Without Exception302
# Data Fetching Continued302
# Passed Without Exception303
# Data Fetching Continued303
# Passed Without Exception304
# Data Fetching Continued304
# Passed Without Exception305
# Data Fetching Continued305
# Passed Without Exception306
# Data Fetching Continued306
# Passed Without Exception307
# Data Fetching Continued307
# Passed Without Exception308
# Data Fetching Continued308
# Passed Without Exception309
# Data Fetching Continued309
# Passed Without Exception310
# Data Fetching Continued310
# Passed Without Exception311
# Data Fetching Continued311
# Passed Without Exception312
# Data Fetching Continued312
# Passed Without Exception313
# Data Fetching Continued313
# Passed Without Exception314
# Data Fetching Continued314
# Passed Without Exception315
# Data Fetching Continued315
# Passed Without Exception316
# Data Fetching Continued316
# Passed Without Exception317
# Data Fetching Continued317
# Passed Without Exception318
# Data Fetching Continued318
# Passed Without Exception319
# Data Fetching Continued319
# Passed Without Exception320
# Data Fetching Continued320
# Passed Without Exception321
# Data Fetching Continued321
# Passed Without Exception322
# Data Fetching Continued322
# Passed Without Exception323
# Data Fetching Continued323
# Passed Without Exception324
# Data Fetching Continued324
# Passed Without Exception325
# Data Fetching Continued325
# Passed Without Exception326
# Data Fetching Continued326
# Passed Without Exception327
# Data Fetching Continued327
# Passed Without Exception328
# Data Fetching Continued328
# Passed Without Exception329
# Data Fetching Continued329
# Passed Without Exception330
# Data Fetching Continued330
# Passed Without Exception331
# Data Fetching Continued331
# Passed Without Exception332
# Data Fetching Continued332
# Passed Without Exception333
# Data Fetching Continued333
# Passed Without Exception334
# Data Fetching Continued334
# Passed Without Exception335
# Data Fetching Continued335
# Passed Without Exception336
# Data Fetching Continued336
# Passed Without Exception337
# Data Fetching Continued337
# Passed Without Exception338
# Data Fetching Continued338
# Passed Without Exception339
# Data Fetching Continued339
# Passed Without Exception340
# Data Fetching Continued340
# Passed Without Exception341
# Data Fetching Continued341
# Passed Without Exception342
# Data Fetching Continued342
# Passed Without Exception343
# Data Fetching Continued343
# Passed Without Exception344
# Data Fetching Continued344
# Passed Without Exception345
# Data Fetching Continued345
# Passed Without Exception346
# Data Fetching Continued346
# Passed Without Exception347
# Data Fetching Continued347
# Passed Without Exception348
# Data Fetching Continued348
# Passed Without Exception349
# Data Fetching Continued349
# Passed Without Exception350
# Data Fetching Continued350
# Passed Without Exception351
# Data Fetching Continued351
# Passed Without Exception352
# Data Fetching Continued352
# Passed Without Exception353
# Data Fetching Continued353
# Passed Without Exception354
# Data Fetching Continued354
# Passed Without Exception355
# Data Fetching Continued355
# Passed Without Exception356
# Data Fetching Continued356
# Passed Without Exception357
# Data Fetching Continued357
# Passed Without Exception358
# Data Fetching Continued358
# Passed Without Exception359
# Data Fetching Continued359
# Passed Without Exception360
# Data Fetching Continued360
# Passed Without Exception361
# Data Fetching Continued361
# Passed Without Exception362
# Data Fetching Continued362
# Passed Without Exception363
# Data Fetching Continued363
# Passed Without Exception364
# Data Fetching Continued364
# Passed Without Exception365
# Data Fetching Continued365
# Passed Without Exception366
# Data Fetching Continued366
# Passed Without Exception367
# Data Fetching Continued367
# Passed Without Exception368
# Data Fetching Continued368
# Passed Without Exception369
# Data Fetching Continued369
# Passed Without Exception370
# Data Fetching Continued370
# Passed Without Exception371
# Data Fetching Continued371
# Passed Without Exception372
# Data Fetching Continued372
# Passed Without Exception373
# Data Fetching Continued373
# Passed Without Exception374
# Data Fetching Continued374
# Passed Without Exception375
# Data Fetching Continued375
# Passed Without Exception376
# Data Fetching Continued376
# Passed Without Exception377
# Data Fetching Continued377
# Passed Without Exception378
# Data Fetching Continued378
# Passed Without Exception379
# Data Fetching Continued379
# Passed Without Exception380
# Data Fetching Continued380
# Passed Without Exception381
# Data Fetching Continued381
# Passed Without Exception382
# Data Fetching Continued382
# Passed Without Exception383
# Data Fetching Continued383
# Passed Without Exception384
# Data Fetching Continued384
# Passed Without Exception385
# Data Fetching Continued385
# Passed Without Exception386
# Data Fetching Continued386
# Passed Without Exception387
# Data Fetching Continued387
# Passed Without Exception388
# Data Fetching Continued388
# Passed Without Exception389
# Data Fetching Continued389
# Passed Without Exception390
# Data Fetching Continued390
# Passed Without Exception391
# Data Fetching Continued391
# Passed Without Exception392
# Data Fetching Continued392
# Passed Without Exception393
# Data Fetching Continued393
# Passed Without Exception394
# Data Fetching Continued394
# Passed Without Exception395
# Data Fetching Continued395
# Passed Without Exception396
# Data Fetching Continued396
# Passed Without Exception397
# Data Fetching Continued397
# Passed Without Exception398
# Data Fetching Continued398
# Passed Without Exception399
# Data Fetching Continued399
# Passed Without Exception400
# Data Fetching Continued400
# Passed Without Exception401
# Data Fetching Continued401
# Passed Without Exception402
# Data Fetching Continued402
# Passed Without Exception403
# Data Fetching Continued403
# Passed Without Exception404
# Data Fetching Continued404
# Passed Without Exception405
# Data Fetching Continued405
# Passed Without Exception406
# Data Fetching Continued406
# Passed Without Exception407
# Data Fetching Continued407
# Passed Without Exception408
# Data Fetching Continued408
# Passed Without Exception409
# Data Fetching Continued409
# Passed Without Exception410
# Data Fetching Continued410
# Passed Without Exception411
# Data Fetching Continued411
# Passed Without Exception412
# Data Fetching Continued412
# Passed Without Exception413
# Data Fetching Continued413
# Passed Without Exception414
# Data Fetching Continued414
# Passed Without Exception415
# Data Fetching Continued415
# Passed Without Exception416
# Data Fetching Continued416
# Passed Without Exception417
# Data Fetching Continued417
# Passed Without Exception418
# Data Fetching Continued418
# Passed Without Exception419
# Data Fetching Continued419
# Passed Without Exception420
# Data Fetching Continued420
# Passed Without Exception421
# Data Fetching Continued421
# Passed Without Exception422
# Data Fetching Continued422
# Passed Without Exception423
# Data Fetching Continued423
# Passed Without Exception424
# Data Fetching Continued424
# Passed Without Exception425
# Data Fetching Continued425
# Passed Without Exception426
# Data Fetching Continued426
# Passed Without Exception427
# Data Fetching Continued427
# Passed Without Exception428
# Data Fetching Continued428
# Passed Without Exception429
# Data Fetching Continued429
# Passed Without Exception430
# Data Fetching Continued430
# Passed Without Exception431
# Data Fetching Continued431
# Passed Without Exception432
# Data Fetching Continued432
# Passed Without Exception433
# Data Fetching Continued433
# Passed Without Exception434
# Data Fetching Continued434
# Passed Without Exception435
# Data Fetching Continued435
# Passed Without Exception436
# Data Fetching Continued436
# Passed Without Exception437
# Data Fetching Continued437
# Passed Without Exception438
# Data Fetching Continued438
# Passed Without Exception439
# Data Fetching Continued439
# Passed Without Exception440
# Data Fetching Continued440
# Passed Without Exception441
# Data Fetching Continued441
# Passed Without Exception442
# Data Fetching Continued442
# Passed Without Exception443
# Data Fetching Continued443
# Passed Without Exception444
# Data Fetching Continued444
# Passed Without Exception445
# Data Fetching Continued445
# Passed Without Exception446
# Data Fetching Continued446
# Passed Without Exception447
# Data Fetching Continued447
# Passed Without Exception448
# Data Fetching Continued448
# Passed Without Exception449
# Data Fetching Continued449
# Passed Without Exception450
# Data Fetching Continued450
# Passed Without Exception451
# Data Fetching Continued451
# Passed Without Exception452
# Data Fetching Continued452
# Passed Without Exception453
# Data Fetching Continued453
# Passed Without Exception454
# Data Fetching Continued454
# Passed Without Exception455
# Data Fetching Continued455
# Passed Without Exception456
# Data Fetching Continued456
# Passed Without Exception457
# Data Fetching Continued457
# Passed Without Exception458
# Data Fetching Continued458
# Passed Without Exception459
# Data Fetching Continued459
# Passed Without Exception460
# Data Fetching Continued460
# Passed Without Exception461
# Data Fetching Continued461
# Passed Without Exception462
# Data Fetching Continued462
# Passed Without Exception463
# Data Fetching Continued463
# Passed Without Exception464
# Data Fetching Continued464
# Passed Without Exception465
# Data Fetching Continued465
# Passed Without Exception466
# Data Fetching Continued466
# Passed Without Exception467
# Data Fetching Continued467
# Passed Without Exception468
# Data Fetching Continued468
# Passed Without Exception469
# Data Fetching Continued469
# Passed Without Exception470
# Data Fetching Continued470
# Passed Without Exception471
# Data Fetching Continued471
# Passed Without Exception472
# Data Fetching Continued472
# Passed Without Exception473
# Data Fetching Continued473
# Passed Without Exception474
# Data Fetching Continued474
# Passed Without Exception475
# Data Fetching Continued475
# Passed Without Exception476
# Data Fetching Continued476
# Passed Without Exception477
# Data Fetching Continued477
# Passed Without Exception478
# Data Fetching Continued478
# Passed Without Exception479
# Data Fetching Continued479
# Passed Without Exception480
# Data Fetching Continued480
# Passed Without Exception481
# Data Fetching Continued481
# Passed Without Exception482
# Data Fetching Continued482
# Passed Without Exception483
# Data Fetching Continued483
# Passed Without Exception484
# Data Fetching Continued484
# Passed Without Exception485
# Data Fetching Continued485
# Passed Without Exception486
# Data Fetching Continued486
# Passed Without Exception487
# Data Fetching Continued487
# Passed Without Exception488
# Data Fetching Continued488
# Passed Without Exception489
# Data Fetching Continued489
# Passed Without Exception490
# Data Fetching Continued490
# Passed Without Exception491
# Data Fetching Continued491
# Passed Without Exception492
# Data Fetching Continued492
# Passed Without Exception493
# Data Fetching Continued493
# Passed Without Exception494
# Data Fetching Continued494
# Passed Without Exception495
# Data Fetching Continued495
# Passed Without Exception496
# Data Fetching Continued496
# Passed Without Exception497
# Data Fetching Continued497
# Passed Without Exception498
# Data Fetching Continued498
# Passed Without Exception499
# Data Fetching Continued499
# Passed Without Exception500
# Data Fetching Continued500
# Passed Without Exception501
# Data Fetching Continued501
# Passed Without Exception502
# Data Fetching Continued502
# Passed Without Exception503
# Data Fetching Continued503
# Passed Without Exception504
# Data Fetching Continued504
# Passed Without Exception505
# Data Fetching Continued505
# Passed Without Exception506
# Data Fetching Continued506
# Passed Without Exception507
# Data Fetching Continued507
# Passed Without Exception508
# Data Fetching Continued508
# Passed Without Exception509
# Data Fetching Continued509
# Passed Without Exception510
# Data Fetching Continued510
# Passed Without Exception511
# Data Fetching Continued511
# Passed Without Exception512
# Data Fetching Continued512
# Passed Without Exception513
# Data Fetching Continued513
# Passed Without Exception514
# Data Fetching Continued514
# Passed Without Exception515
# Data Fetching Continued515
# Passed Without Exception516
# Data Fetching Continued516
# Passed Without Exception517
# Data Fetching Continued517
# Passed Without Exception518
# Data Fetching Continued518
# Passed Without Exception519
# Data Fetching Continued519
# Passed Without Exception520
# Data Fetching Continued520
# Passed Without Exception521
# Data Fetching Continued521
# Passed Without Exception522
# Data Fetching Continued522
# Passed Without Exception523
# Data Fetching Continued523
# Passed Without Exception524
# Data Fetching Continued524
# Passed Without Exception525
# Data Fetching Continued525
# Passed Without Exception526
# Data Fetching Continued526
# Passed Without Exception527
# Data Fetching Continued527
# Passed Without Exception528
# Data Fetching Continued528
# Passed Without Exception529
# Data Fetching Continued529
# Passed Without Exception530
# Data Fetching Continued530
# Passed Without Exception531
# Data Fetching Continued531
# Passed Without Exception532
# Data Fetching Continued532
# Passed Without Exception533
# Data Fetching Continued533
# Passed Without Exception534
# Data Fetching Continued534
# Passed Without Exception535
# Data Fetching Continued535
# Passed Without Exception536
# Data Fetching Continued536
# Passed Without Exception537
# Data Fetching Continued537
# Passed Without Exception538
# Data Fetching Continued538
# Passed Without Exception539
# Data Fetching Continued539
# Passed Without Exception540
# Data Fetching Continued540
# Passed Without Exception541
# Data Fetching Continued541
# Passed Without Exception542
# Data Fetching Continued542
# Passed Without Exception543
# Data Fetching Continued543
# Passed Without Exception544
# Data Fetching Continued544
# Passed Without Exception545
# Data Fetching Continued545
# Passed Without Exception546
# Data Fetching Continued546
# Passed Without Exception547
# Data Fetching Continued547
# Passed Without Exception548
# Data Fetching Continued548
# Passed Without Exception549
# Data Fetching Continued549
# Passed Without Exception550
# Data Fetching Continued550
# Passed Without Exception551
# Data Fetching Continued551
# Passed Without Exception552
# Data Fetching Continued552
# Passed Without Exception553
# Data Fetching Continued553
# Passed Without Exception554
# Data Fetching Continued554
# Passed Without Exception555
# Data Fetching Continued555
# Passed Without Exception556
# Data Fetching Continued556
# Passed Without Exception557
# Data Fetching Continued557
# Passed Without Exception558
# Data Fetching Continued558
# Passed Without Exception559
# Data Fetching Continued559
# Passed Without Exception560
# Data Fetching Continued560
# Passed Without Exception561
# Data Fetching Continued561
# Passed Without Exception562
# Data Fetching Continued562
# Passed Without Exception563
# Data Fetching Continued563
# Passed Without Exception564
# Data Fetching Continued564
# Passed Without Exception565
# Data Fetching Continued565
# Passed Without Exception566
# Data Fetching Continued566
# Passed Without Exception567
# Data Fetching Continued567
# Passed Without Exception568
# Data Fetching Continued568
# Passed Without Exception569
# Data Fetching Continued569
# Passed Without Exception570
# Data Fetching Continued570
# Passed Without Exception571
# Data Fetching Continued571
# Passed Without Exception572
# Data Fetching Continued572
# Passed Without Exception573
# Data Fetching Continued573
# Passed Without Exception574
# Data Fetching Continued574
# Passed Without Exception575
# Data Fetching Continued575
# Passed Without Exception576
# Data Fetching Continued576
# Passed Without Exception577
# Data Fetching Continued577
# Passed Without Exception578
# Data Fetching Continued578
# Passed Without Exception579
# Data Fetching Continued579
# Passed Without Exception580
# Data Fetching Continued580
# Passed Without Exception581
# Data Fetching Continued581
# Passed Without Exception582
# Data Fetching Continued582
# Passed Without Exception583
# Data Fetching Continued583
# Passed Without Exception584
# Data Fetching Continued584
# Passed Without Exception585
# Data Fetching Continued585
# Passed Without Exception586
# Data Fetching Continued586
# Passed Without Exception587
# Data Fetching Continued587
# Passed Without Exception588
# Data Fetching Continued588
# Passed Without Exception589
# Data Fetching Continued589
# Passed Without Exception590
# Data Fetching Continued590
# Passed Without Exception591
# Data Fetching Continued591
# Passed Without Exception592
# Data Fetching Continued592
# Passed Without Exception593
# Data Fetching Continued593
# Passed Without Exception594
# Data Fetching Continued594
# Passed Without Exception595
# Data Fetching Continued595
# Passed Without Exception596
# Data Fetching Continued596
# Passed Without Exception597
# Data Fetching Continued597
# Passed Without Exception598
# Data Fetching Continued598
# Passed Without Exception599
# Data Fetching Continued599
# Passed Without Exception600
# Data Fetching Continued600
# Passed Without Exception601
# Data Fetching Continued601
# Passed Without Exception602
# Data Fetching Continued602
# Passed Without Exception603
# Data Fetching Continued603
# Passed Without Exception604
# Data Fetching Continued604
# Passed Without Exception605
# Data Fetching Continued605
# Passed Without Exception606
# Data Fetching Continued606
# Passed Without Exception607
# Data Fetching Continued607
# Passed Without Exception608
# Data Fetching Continued608
# Passed Without Exception609
# Data Fetching Continued609
# Passed Without Exception610
# Data Fetching Continued610
# Passed Without Exception611
# Data Fetching Continued611
# Passed Without Exception612
# Data Fetching Continued612
# Passed Without Exception613
# Data Fetching Continued613
# Passed Without Exception614
# Data Fetching Continued614
# Passed Without Exception615
# Data Fetching Continued615
# Passed Without Exception616
# Data Fetching Continued616
# Passed Without Exception617
# Data Fetching Continued617
# Passed Without Exception618
# Data Fetching Continued618
# Passed Without Exception619
# Data Fetching Continued619
# Passed Without Exception620
# Data Fetching Continued620
# Passed Without Exception621
# Data Fetching Continued621
# Passed Without Exception622
# Data Fetching Continued622
# Passed Without Exception623
# Data Fetching Continued623
# Passed Without Exception624
# Data Fetching Continued624
# Passed Without Exception625
# Data Fetching Continued625
# Passed Without Exception626
# Data Fetching Continued626
# Passed Without Exception627
# Data Fetching Continued627
# Passed Without Exception628
# Data Fetching Continued628
# Passed Without Exception629
# Data Fetching Continued629
# Passed Without Exception630
# Data Fetching Continued630
# Passed Without Exception631
# Data Fetching Continued631
# Passed Without Exception632
# Data Fetching Continued632
# Passed Without Exception633
# Data Fetching Continued633
# Passed Without Exception634
# Data Fetching Continued634
# Passed Without Exception635
# Data Fetching Continued635
# Passed Without Exception636
# Data Fetching Continued636
# Passed Without Exception637
# Data Fetching Continued637
# Passed Without Exception638
# Data Fetching Continued638
# Passed Without Exception639
# Data Fetching Continued639
# Passed Without Exception640
# Data Fetching Continued640
# Passed Without Exception641
# Data Fetching Continued641
# Passed Without Exception642
# Data Fetching Continued642
# Passed Without Exception643
# Data Fetching Continued643
# Passed Without Exception644
# Data Fetching Continued644
# Passed Without Exception645
# Data Fetching Continued645
# Passed Without Exception646
# Data Fetching Continued646
# Passed Without Exception647
# Data Fetching Continued647
# Passed Without Exception648
# Data Fetching Continued648
# Passed Without Exception649
# Data Fetching Continued649
# Passed Without Exception650
# Data Fetching Continued650
# Passed Without Exception651
# Data Fetching Continued651
# Passed Without Exception652
# Data Fetching Continued652
# Passed Without Exception653
# Data Fetching Continued653
# Passed Without Exception654
# Data Fetching Continued654
# Passed Without Exception655
# Data Fetching Continued655
# Passed Without Exception656
# Data Fetching Continued656
# Passed Without Exception657
# Data Fetching Continued657
# Passed Without Exception658
# Data Fetching Continued658
# Passed Without Exception659
# Data Fetching Continued659
# Passed Without Exception660
# Data Fetching Continued660
# Passed Without Exception661
# Data Fetching Continued661
# Passed Without Exception662
# Data Fetching Continued662
# Passed Without Exception663
# Data Fetching Continued663
# Passed Without Exception664
# Data Fetching Continued664
# Passed Without Exception665
# Data Fetching Continued665
# Passed Without Exception666
# Data Fetching Continued666
# Passed Without Exception667
# Data Fetching Continued667
# Passed Without Exception668
# Data Fetching Continued668
# Passed Without Exception669
# Data Fetching Continued669
# Passed Without Exception670
# Data Fetching Continued670
# Passed Without Exception671
# Data Fetching Continued671
# Passed Without Exception672
# Data Fetching Continued672
# Passed Without Exception673
# Data Fetching Continued673
# Passed Without Exception674
# Data Fetching Continued674
# Passed Without Exception675
# Data Fetching Continued675
# Passed Without Exception676
# Data Fetching Continued676
# Passed Without Exception677
# Data Fetching Continued677
# Passed Without Exception678
# Data Fetching Continued678
# Passed Without Exception679
# Data Fetching Continued679
# Passed Without Exception680
# Data Fetching Continued680
# Passed Without Exception681
# Data Fetching Continued681
# Passed Without Exception682
# Data Fetching Continued682
# Passed Without Exception683
# Data Fetching Continued683
# Passed Without Exception684
# Data Fetching Continued684
# Passed Without Exception685
# Data Fetching Continued685
# Passed Without Exception686
# Data Fetching Continued686
# Passed Without Exception687
# Data Fetching Continued687
# Passed Without Exception688
# Data Fetching Continued688
# Passed Without Exception689
# Data Fetching Continued689
# Passed Without Exception690
# Data Fetching Continued690
# Passed Without Exception691
# Data Fetching Continued691
# Passed Without Exception692
# Data Fetching Continued692
# Passed Without Exception693
# Data Fetching Continued693
# Passed Without Exception694
# Data Fetching Continued694
# Passed Without Exception695
# Data Fetching Continued695
# Passed Without Exception696
# Data Fetching Continued696
# Passed Without Exception697
# Data Fetching Continued697
# Passed Without Exception698
# Data Fetching Continued698
# Passed Without Exception699
# Data Fetching Continued699
# Passed Without Exception700
# Data Fetching Continued700
# Passed Without Exception701
# Data Fetching Continued701
# Passed Without Exception702
# Data Fetching Continued702
# Passed Without Exception703
# Data Fetching Continued703
# Passed Without Exception704
# Data Fetching Continued704
# Passed Without Exception705
# Data Fetching Continued705
# Passed Without Exception706
# Data Fetching Continued706
# Passed Without Exception707
# Data Fetching Continued707
# Passed Without Exception708
# Data Fetching Continued708
# Passed Without Exception709
# Data Fetching Continued709
# Passed Without Exception710
# Data Fetching Continued710
# Passed Without Exception711
# Data Fetching Continued711
# Passed Without Exception712
# Data Fetching Continued712
# Passed Without Exception713
# Data Fetching Continued713
# Passed Without Exception714
# Data Fetching Continued714
# Passed Without Exception715
# Data Fetching Continued715
# Passed Without Exception716
# Data Fetching Continued716
# Passed Without Exception717
# Data Fetching Continued717
# Passed Without Exception718
# Data Fetching Continued718
# Passed Without Exception719
# Data Fetching Continued719
# Passed Without Exception720
# Data Fetching Continued720
# Passed Without Exception721
# Data Fetching Continued721
# Passed Without Exception722
# Data Fetching Continued722
# Passed Without Exception723
# Data Fetching Continued723
# Passed Without Exception724
# Data Fetching Continued724
# Passed Without Exception725
# Data Fetching Continued725
# Passed Without Exception726
# Data Fetching Continued726
# Passed Without Exception727
# Data Fetching Continued727
# Passed Without Exception728
# Data Fetching Continued728
# Passed Without Exception729
# Data Fetching Continued729
# Passed Without Exception730
# Data Fetching Continued730
# Passed Without Exception731
# Data Fetching Continued731
# Passed Without Exception732
# Data Fetching Continued732
# Passed Without Exception733
# Data Fetching Continued733
# Passed Without Exception734
# Data Fetching Continued734
# Passed Without Exception735
# Data Fetching Continued735
# Passed Without Exception736
# Data Fetching Continued736
# Passed Without Exception737
# Data Fetching Continued737
# Passed Without Exception738
# Data Fetching Continued738
# Passed Without Exception739
# Data Fetching Continued739
# Passed Without Exception740
# Data Fetching Continued740
# Passed Without Exception741
# Data Fetching Continued741
# Passed Without Exception742
# Data Fetching Continued742
# Passed Without Exception743
# Data Fetching Continued743
# Passed Without Exception744
# Data Fetching Continued744
# Passed Without Exception745
# Data Fetching Continued745
# Passed Without Exception746
# Data Fetching Continued746
# Passed Without Exception747
# Data Fetching Continued747
# Passed Without Exception748
# Data Fetching Continued748
# Passed Without Exception749
# Data Fetching Continued749
# Passed Without Exception750
# Data Fetching Continued750
# Passed Without Exception751
# Data Fetching Continued751
# Passed Without Exception752
# Data Fetching Continued752
# Passed Without Exception753
# Data Fetching Continued753
# Passed Without Exception754
# Data Fetching Continued754
# Passed Without Exception755
# Data Fetching Continued755
# Passed Without Exception756
# Data Fetching Continued756
# Passed Without Exception757
# Data Fetching Continued757
# Passed Without Exception758
# Data Fetching Continued758
# Passed Without Exception759
# Data Fetching Continued759
# Passed Without Exception760
# Data Fetching Continued760
# Passed Without Exception761
# Data Fetching Continued761
# Passed Without Exception762
# Data Fetching Continued762
# Passed Without Exception763
# Data Fetching Continued763
# Passed Without Exception764
# Data Fetching Continued764
# Passed Without Exception765
# Data Fetching Continued765
# Passed Without Exception766
# Data Fetching Continued766
# Passed Without Exception767
# Data Fetching Continued767
# Passed Without Exception768
# Data Fetching Continued768
# Passed Without Exception769
# Data Fetching Continued769
# Passed Without Exception770
# Data Fetching Continued770
# Passed Without Exception771
# Data Fetching Continued771
# Passed Without Exception772
# Data Fetching Continued772
# Passed Without Exception773
# Data Fetching Continued773
# Passed Without Exception774
# Data Fetching Continued774
# Passed Without Exception775
# Data Fetching Continued775
# Passed Without Exception776
# Data Fetching Continued776
# Passed Without Exception777
# Data Fetching Continued777
# Passed Without Exception778
# Data Fetching Continued778
# Passed Without Exception779
# Data Fetching Continued779
# Passed Without Exception780
# Data Fetching Continued780
# Passed Without Exception781
# Data Fetching Continued781
# Passed Without Exception782
# Data Fetching Continued782
# Passed Without Exception783
# Data Fetching Continued783
# Passed Without Exception784
# Data Fetching Continued784
# Passed Without Exception785
# Data Fetching Continued785
# Passed Without Exception786
# Data Fetching Continued786
# Passed Without Exception787
# Data Fetching Continued787
# Passed Without Exception788
# Data Fetching Continued788
# Passed Without Exception789
# Data Fetching Continued789
# Passed Without Exception790
# Data Fetching Continued790
# Passed Without Exception791
# Data Fetching Continued791
# Passed Without Exception792
# Data Fetching Continued792
# Passed Without Exception793
# Data Fetching Continued793
# Passed Without Exception794
# Data Fetching Continued794
# Passed Without Exception795
# Data Fetching Continued795
# Passed Without Exception796
# Data Fetching Continued796
# Passed Without Exception797
# Data Fetching Continued797
# Passed Without Exception798
# Data Fetching Continued798
# Passed Without Exception799
# Data Fetching Continued799
# Passed Without Exception800
# Data Fetching Continued800
# Passed Without Exception801
# Data Fetching Continued801
# Passed Without Exception802
# Data Fetching Continued802
# Passed Without Exception803
# Data Fetching Continued803
# Passed Without Exception804
# Data Fetching Continued804
# Passed Without Exception805
# Data Fetching Continued805
# Passed Without Exception806
# Data Fetching Continued806
# Passed Without Exception807
# Data Fetching Continued807
# Passed Without Exception808
# Data Fetching Continued808
# Passed Without Exception809
# Data Fetching Continued809
# Passed Without Exception810
# Data Fetching Continued810
# Passed Without Exception811
# Data Fetching Continued811
# Passed Without Exception812
# Data Fetching Continued812
# Passed Without Exception813
# Data Fetching Continued813
# Passed Without Exception814
# Data Fetching Continued814
# Passed Without Exception815
# Data Fetching Continued815
# Passed Without Exception816
# Data Fetching Continued816
# Passed Without Exception817
# Data Fetching Continued817
# Passed Without Exception818
# Data Fetching Continued818
# Passed Without Exception819
# Data Fetching Continued819
# Passed Without Exception820
# Data Fetching Continued820
# Passed Without Exception821
# Data Fetching Continued821
# Passed Without Exception822
# Data Fetching Continued822
# Passed Without Exception823
# Data Fetching Continued823
# Passed Without Exception824
# Data Fetching Continued824
# Passed Without Exception825
# Data Fetching Continued825
# Passed Without Exception826
# Data Fetching Continued826
# Passed Without Exception827
# Data Fetching Continued827
# Passed Without Exception828
# Data Fetching Continued828
# Passed Without Exception829
# Data Fetching Continued829
# Passed Without Exception830
# Data Fetching Continued830
# Passed Without Exception831
# Data Fetching Continued831
# Passed Without Exception832
# Data Fetching Continued832
# Passed Without Exception833
# Data Fetching Continued833
# Passed Without Exception834
# Data Fetching Continued834
# Passed Without Exception835
# Data Fetching Continued835
# Passed Without Exception836
# Data Fetching Continued836
# Passed Without Exception837
# Data Fetching Continued837
# Passed Without Exception838
# Data Fetching Continued838
# Passed Without Exception839
# Data Fetching Continued839
# Passed Without Exception840
# Data Fetching Continued840
# Passed Without Exception841
# Data Fetching Continued841
# Passed Without Exception842
# Data Fetching Continued842
# Passed Without Exception843
# Data Fetching Continued843
# Passed Without Exception844
# Data Fetching Continued844
# Passed Without Exception845
# Data Fetching Continued845
# Passed Without Exception846
# Data Fetching Continued846
# Passed Without Exception847
# Data Fetching Continued847
# Passed Without Exception848
# Data Fetching Continued848
# Passed Without Exception849
# Data Fetching Continued849
# Passed Without Exception850
# Data Fetching Continued850
# Passed Without Exception851
# Data Fetching Continued851
# Passed Without Exception852
# Data Fetching Continued852
# Passed Without Exception853
# Data Fetching Continued853
# Passed Without Exception854
# Data Fetching Continued854
# Passed Without Exception855
# Data Fetching Continued855
# Passed Without Exception856
# Data Fetching Continued856
# Passed Without Exception857
# Data Fetching Continued857
# Passed Without Exception858
# Data Fetching Continued858
# Passed Without Exception859
# Data Fetching Continued859
# Passed Without Exception860
# Data Fetching Continued860
# Passed Without Exception861
# Data Fetching Continued861
# Passed Without Exception862
# Data Fetching Continued862
# Passed Without Exception863
# Data Fetching Continued863
# Passed Without Exception864
# Data Fetching Continued864
# Passed Without Exception865
# Data Fetching Continued865
# Passed Without Exception866
# Data Fetching Continued866
# Passed Without Exception867
# Data Fetching Continued867
# Passed Without Exception868
# Data Fetching Continued868
# Passed Without Exception869
# Data Fetching Continued869
# Passed Without Exception870
# Data Fetching Continued870
# Passed Without Exception871
# Data Fetching Continued871
# Passed Without Exception872
# Data Fetching Continued872
# Passed Without Exception873
# Data Fetching Continued873
# Passed Without Exception874
# Data Fetching Continued874
# Passed Without Exception875
# Data Fetching Continued875
# Passed Without Exception876
# Data Fetching Continued876
# Passed Without Exception877
# ...
# Data Fetching Continued2566
# Passed Without Exception2567
# Data Fetching Continued2567
# Passed Without Exception2568
# Data Fetching Continued2568
# Passed Without Exception2569
# Data Fetching Continued2569
# Passed Without Exception2570
# Data Fetching Continued2570
# Passed Without Exception2571
# Data Fetching Continued2571
# Passed Without Exception2572
# Data Fetching Continued2572
# Passed Without Exception2573
# Data Fetching Continued2573
# Passed Without Exception2574
# Data Fetching Continued2574
# Passed Without Exception2575
# Data Fetching Continued2575
# Passed Without Exception2576
# Data Fetching Continued2576
# Passed Without Exception2577
# Data Fetching Continued2577
# Passed Without Exception2578
# Data Fetching Continued2578
# Passed Without Exception2579
# Data Fetching Continued2579
# Passed Without Exception2580
# Data Fetching Continued2580
# Passed Without Exception2581
# Data Fetching Continued2581
# Passed Without Exception2582
# Data Fetching Continued2582
# Passed Without Exception2583
# Data Fetching Continued2583
# Passed Without Exception2584
# Data Fetching Continued2584
# Passed Without Exception2585
# Data Fetching Continued2585
# Passed Without Exception2586
# Data Fetching Continued2586
# Passed Without Exception2587
# Data Fetching Continued2587
# Passed Without Exception2588
# Data Fetching Continued2588
# Passed Without Exception2589
# Data Fetching Continued2589
# Passed Without Exception2590
# Data Fetching Continued2590
# Passed Without Exception2591
# Data Fetching Continued2591
# Passed Without Exception2592
# Data Fetching Continued2592
# Passed Without Exception2593
# Data Fetching Continued2593
# Passed Without Exception2594
# Data Fetching Continued2594
# Passed Without Exception2595
# Data Fetching Continued2595
# Passed Without Exception2596
# Data Fetching Continued2596
# Passed Without Exception2597
# Data Fetching Continued2597
# Passed Without Exception2598
# Data Fetching Continued2598
# Passed Without Exception2599
# Data Fetching Continued2599
# Passed Without Exception2600
# Data Fetching Continued2600
# Passed Without Exception2601
# Data Fetching Continued2601
# Passed Without Exception2602
# Data Fetching Continued2602
# Passed Without Exception2603
# Data Fetching Continued2603
# Passed Without Exception2604
# Data Fetching Continued2604
# Passed Without Exception2605
# Data Fetching Continued2605
# Passed Without Exception2606
# Data Fetching Continued2606
# Passed Without Exception2607
# Data Fetching Continued2607
# Passed Without Exception2608
# Data Fetching Continued2608
# Passed Without Exception2609
# Data Fetching Continued2609
# Passed Without Exception2610
# Data Fetching Continued2610
# Passed Without Exception2611
# Data Fetching Continued2611
# Passed Without Exception2612
# Data Fetching Continued2612
# Passed Without Exception2613
# Data Fetching Continued2613
# Passed Without Exception2614
# Data Fetching Continued2614
# Passed Without Exception2615
# Data Fetching Continued2615
# Passed Without Exception2616
# Data Fetching Continued2616
# Passed Without Exception2617
# Data Fetching Continued2617
# Passed Without Exception2618
# Data Fetching Continued2618
# Passed Without Exception2619
# Data Fetching Continued2619
# Passed Without Exception2620
# Data Fetching Continued2620
# Passed Without Exception2621
# Data Fetching Continued2621
# Passed Without Exception2622
# Data Fetching Continued2622
# Passed Without Exception2623
# Data Fetching Continued2623
# Passed Without Exception2624
# Data Fetching Continued2624
# Passed Without Exception2625
# Data Fetching Continued2625
# Passed Without Exception2626
# Data Fetching Continued2626
# Passed Without Exception2627
# Data Fetching Continued2627
# Passed Without Exception2628
# Data Fetching Continued2628
# Passed Without Exception2629
# Data Fetching Continued2629
# Passed Without Exception2630
# Data Fetching Continued2630
# Passed Without Exception2631
# Data Fetching Continued2631
# Passed Without Exception2632
# Data Fetching Continued2632
# Passed Without Exception2633
# Data Fetching Continued2633
# Passed Without Exception2634
# Data Fetching Continued2634
# Passed Without Exception2635
# Data Fetching Continued2635
# Passed Without Exception2636
# Data Fetching Continued2636
# Passed Without Exception2637
# Data Fetching Continued2637
# Passed Without Exception2638
# Data Fetching Continued2638
# Passed Without Exception2639
# Data Fetching Continued2639
# Passed Without Exception2640
# Data Fetching Continued2640
# Passed Without Exception2641
# Data Fetching Continued2641
# Passed Without Exception2642
# Data Fetching Continued2642
# Passed Without Exception2643
# Data Fetching Continued2643
# Passed Without Exception2644
# Data Fetching Continued2644
# Passed Without Exception2645
# Data Fetching Continued2645
# Passed Without Exception2646
# Data Fetching Continued2646
# Passed Without Exception2647
# Data Fetching Continued2647
# Passed Without Exception2648
# Data Fetching Continued2648
# Passed Without Exception2649
# Data Fetching Continued2649
# Passed Without Exception2650
# Data Fetching Continued2650
# Passed Without Exception2651
# Data Fetching Continued2651
# Passed Without Exception2652
# Data Fetching Continued2652
# Passed Without Exception2653
# Data Fetching Continued2653
# Passed Without Exception2654
# Data Fetching Continued2654
# Passed Without Exception2655
# Data Fetching Continued2655
# Passed Without Exception2656
# Data Fetching Continued2656
# Passed Without Exception2657
# Data Fetching Continued2657
# Passed Without Exception2658
# Data Fetching Continued2658
# Passed Without Exception2659
# Data Fetching Continued2659
# Passed Without Exception2660
# Data Fetching Continued2660
# Passed Without Exception2661
# Data Fetching Continued2661
# Passed Without Exception2662
# Data Fetching Continued2662
# Passed Without Exception2663
# Data Fetching Continued2663
# Passed Without Exception2664
# Data Fetching Continued2664
# Passed Without Exception2665
# Data Fetching Continued2665
# Passed Without Exception2666
# Data Fetching Continued2666
# Passed Without Exception2667
# Data Fetching Continued2667
# Passed Without Exception2668
# Data Fetching Continued2668
# Passed Without Exception2669
# Data Fetching Continued2669
# Passed Without Exception2670
# Data Fetching Continued2670
# Passed Without Exception2671
# Data Fetching Continued2671
# Passed Without Exception2672
# Data Fetching Continued2672
# Passed Without Exception2673
# Data Fetching Continued2673
# Passed Without Exception2674
# Data Fetching Continued2674
# Passed Without Exception2675
# Data Fetching Continued2675
# Passed Without Exception2676
# Data Fetching Continued2676
# Passed Without Exception2677
# Data Fetching Continued2677
# Passed Without Exception2678
# Data Fetching Continued2678
# Passed Without Exception2679
# Data Fetching Continued2679
# Passed Without Exception2680
# Data Fetching Continued2680
# Passed Without Exception2681
# Data Fetching Continued2681
# Passed Without Exception2682
# Data Fetching Continued2682
# Passed Without Exception2683
# Data Fetching Continued2683
# Passed Without Exception2684
# Data Fetching Continued2684
# Passed Without Exception2685
# Data Fetching Continued2685
# Passed Without Exception2686
# Data Fetching Continued2686
# Passed Without Exception2687
# Data Fetching Continued2687
# Passed Without Exception2688
# Data Fetching Continued2688
# Passed Without Exception2689
# Data Fetching Continued2689
# Passed Without Exception2690
# Data Fetching Continued2690
# Passed Without Exception2691
# Data Fetching Continued2691
# Passed Without Exception2692
# Data Fetching Continued2692
# Passed Without Exception2693
# Data Fetching Continued2693
# Passed Without Exception2694
# Data Fetching Continued2694
# Passed Without Exception2695
# Data Fetching Continued2695
# Passed Without Exception2696
# Data Fetching Continued2696
# Passed Without Exception2697
# Data Fetching Continued2697
# Passed Without Exception2698
# Data Fetching Continued2698
# Passed Without Exception2699
# Data Fetching Continued2699
# Passed Without Exception2700
# Data Fetching Continued2700
# Passed Without Exception2701
# Data Fetching Continued2701
# Passed Without Exception2702
# Data Fetching Continued2702
# Passed Without Exception2703
# Data Fetching Continued2703
# Passed Without Exception2704
# Data Fetching Continued2704
# Passed Without Exception2705
# Data Fetching Continued2705
# Passed Without Exception2706
# Data Fetching Continued2706
# Passed Without Exception2707
# Data Fetching Continued2707
# Passed Without Exception2708
# Data Fetching Continued2708
# Passed Without Exception2709
# Data Fetching Continued2709
# Passed Without Exception2710
# Data Fetching Continued2710
# Passed Without Exception2711
# Data Fetching Continued2711
# Passed Without Exception2712
# Data Fetching Continued2712
# Passed Without Exception2713
# Data Fetching Continued2713
# Passed Without Exception2714
# Data Fetching Continued2714
# Passed Without Exception2715
# Data Fetching Continued2715
# Passed Without Exception2716
# Data Fetching Continued2716
# Passed Without Exception2717
# Data Fetching Continued2717
# Passed Without Exception2718
# Data Fetching Continued2718
# Passed Without Exception2719
# Data Fetching Continued2719
# Passed Without Exception2720
# Data Fetching Continued2720
# Passed Without Exception2721
# Data Fetching Continued2721
# Passed Without Exception2722
# Data Fetching Continued2722
# Passed Without Exception2723
# Data Fetching Continued2723
# Passed Without Exception2724
# Data Fetching Continued2724
# Passed Without Exception2725
# Data Fetching Continued2725
# Passed Without Exception2726
# Data Fetching Continued2726
# Passed Without Exception2727
# Data Fetching Continued2727
# Passed Without Exception2728
# Data Fetching Continued2728
# Passed Without Exception2729
# Data Fetching Continued2729
# Passed Without Exception2730
# Data Fetching Continued2730
# Passed Without Exception2731
# Data Fetching Continued2731
# Passed Without Exception2732
# Data Fetching Continued2732
# Passed Without Exception2733
# Data Fetching Continued2733
# Passed Without Exception2734
# Data Fetching Continued2734
# Passed Without Exception2735
# Data Fetching Continued2735
# Passed Without Exception2736
# Data Fetching Continued2736
# Passed Without Exception2737
# Data Fetching Continued2737
# Passed Without Exception2738
# Data Fetching Continued2738
# Passed Without Exception2739
# Data Fetching Continued2739
# Passed Without Exception2740
# Data Fetching Continued2740
# Passed Without Exception2741
# Data Fetching Continued2741
# Passed Without Exception2742
# Data Fetching Continued2742
# Passed Without Exception2743
# Data Fetching Continued2743
# Passed Without Exception2744
# Data Fetching Continued2744
# Passed Without Exception2745
# Data Fetching Continued2745
# Passed Without Exception2746
# Data Fetching Continued2746
# Passed Without Exception2747
# Data Fetching Continued2747
# Passed Without Exception2748
# Data Fetching Continued2748
# Passed Without Exception2749
# Data Fetching Continued2749
# Passed Without Exception2750
# Data Fetching Continued2750
# Passed Without Exception2751
# Data Fetching Continued2751
# Passed Without Exception2752
# Data Fetching Continued2752
# Passed Without Exception2753
# Data Fetching Continued2753
# Passed Without Exception2754
# Data Fetching Continued2754
# Passed Without Exception2755
# Data Fetching Continued2755
# Passed Without Exception2756
# Data Fetching Continued2756
# Passed Without Exception2757
# Data Fetching Continued2757
# Passed Without Exception2758
# Data Fetching Continued2758
# Passed Without Exception2759
# Data Fetching Continued2759
# Passed Without Exception2760
# Data Fetching Continued2760
# Passed Without Exception2761
# Data Fetching Continued2761
# Passed Without Exception2762
# Data Fetching Continued2762
# Passed Without Exception2763
# Data Fetching Continued2763
# Passed Without Exception2764
# Data Fetching Continued2764
# Passed Without Exception2765
# Data Fetching Continued2765
# Passed Without Exception2766
# Data Fetching Continued2766
# Passed Without Exception2767
# Data Fetching Continued2767
# Passed Without Exception2768
# Data Fetching Continued2768
# Passed Without Exception2769
# Data Fetching Continued2769
# Passed Without Exception2770
# Data Fetching Continued2770
# Passed Without Exception2771
# Data Fetching Continued2771
# Passed Without Exception2772
# Data Fetching Continued2772
# Passed Without Exception2773
# Data Fetching Continued2773
# Passed Without Exception2774
# Data Fetching Continued2774
# Passed Without Exception2775
# Data Fetching Continued2775
# Passed Without Exception2776
# Data Fetching Continued2776
# Passed Without Exception2777
# Data Fetching Continued2777
# Passed Without Exception2778
# Data Fetching Continued2778
# Passed Without Exception2779
# Data Fetching Continued2779
# Passed Without Exception2780
# Data Fetching Continued2780
# Passed Without Exception2781
# Data Fetching Continued2781
# Passed Without Exception2782
# Data Fetching Continued2782
# Passed Without Exception2783
# Data Fetching Continued2783
# Passed Without Exception2784
# Data Fetching Continued2784
# Passed Without Exception2785
# Data Fetching Continued2785
# Passed Without Exception2786
# Data Fetching Continued2786
# Passed Without Exception2787
# Data Fetching Continued2787
# Passed Without Exception2788
# Data Fetching Continued2788
# Passed Without Exception2789
# Data Fetching Continued2789
# Passed Without Exception2790
# Data Fetching Continued2790
# Passed Without Exception2791
# Data Fetching Continued2791
# Passed Without Exception2792
# Data Fetching Continued2792
# Passed Without Exception2793
# Data Fetching Continued2793
# Passed Without Exception2794
# Data Fetching Continued2794
# Passed Without Exception2795
# Data Fetching Continued2795
# Passed Without Exception2796
# Data Fetching Continued2796
# Passed Without Exception2797
# Data Fetching Continued2797
# Passed Without Exception2798
# Data Fetching Continued2798
# Passed Without Exception2799
# Data Fetching Continued2799
# Passed Without Exception2800
# Data Fetching Continued2800
# Passed Without Exception2801
# Data Fetching Continued2801
# Passed Without Exception2802
# Data Fetching Continued2802
# Passed Without Exception2803
# Data Fetching Continued2803
# Passed Without Exception2804
# Data Fetching Continued2804
# Passed Without Exception2805
# Data Fetching Continued2805
# Passed Without Exception2806
# Data Fetching Continued2806
# Passed Without Exception2807
# Data Fetching Continued2807
# Passed Without Exception2808
# Data Fetching Continued2808
# Passed Without Exception2809
# Data Fetching Continued2809
# Passed Without Exception2810
# Data Fetching Continued2810
# Passed Without Exception2811
# Data Fetching Continued2811
# Passed Without Exception2812
# Data Fetching Continued2812
# Passed Without Exception2813
# Data Fetching Continued2813
# Passed Without Exception2814
# Data Fetching Continued2814
# Passed Without Exception2815
# Data Fetching Continued2815
# Passed Without Exception2816
# Data Fetching Continued2816
# Passed Without Exception2817
# Data Fetching Continued2817
# Passed Without Exception2818
# Data Fetching Continued2818
# Passed Without Exception2819
# Data Fetching Continued2819
# Passed Without Exception2820
# Data Fetching Continued2820
# Passed Without Exception2821
# Data Fetching Continued2821
# Passed Without Exception2822
# Data Fetching Continued2822
# Passed Without Exception2823
# Data Fetching Continued2823
# Passed Without Exception2824
# Data Fetching Continued2824
# Passed Without Exception2825
# Data Fetching Continued2825
# Passed Without Exception2826
# Data Fetching Continued2826
# Passed Without Exception2827
# Data Fetching Continued2827
# Passed Without Exception2828
# Data Fetching Continued2828
# Passed Without Exception2829
# Data Fetching Continued2829
# Passed Without Exception2830
# Data Fetching Continued2830
# Passed Without Exception2831
# Data Fetching Continued2831
# Passed Without Exception2832
# Data Fetching Continued2832
# Passed Without Exception2833
# Data Fetching Continued2833
# Passed Without Exception2834
# Data Fetching Continued2834
# Passed Without Exception2835
# Data Fetching Continued2835
# Passed Without Exception2836
# Data Fetching Continued2836
# Passed Without Exception2837
# Data Fetching Continued2837
# Passed Without Exception2838
# Data Fetching Continued2838
# Passed Without Exception2839
# Data Fetching Continued2839
# Passed Without Exception2840
# Data Fetching Continued2840
# Passed Without Exception2841
# Data Fetching Continued2841
# Passed Without Exception2842
# Data Fetching Continued2842
# Passed Without Exception2843
# Data Fetching Continued2843
# Passed Without Exception2844
# Data Fetching Continued2844
# Passed Without Exception2845
# Data Fetching Continued2845
# Passed Without Exception2846
# Data Fetching Continued2846

# %% [markdown]
# # Auto-QSAR And Drug-Lead Generation

# %%
final_data_frame.shape
# Out:
# (1142, 9)

# %%
#condition
#final_data_frame= pd.read_csv("Final_datacsv_test1.csv")

# %%
#condition
#final_data_frame.drop(columns="Unnamed: 0",inplace = True)

# %%
final_data_frame.drop_duplicates(inplace=True)

# %%
print("The Final Training DataSet: X_data = {} , Y_data = {}".format(x_data.shape,y_data.shape))
# Out:
# The Final Training DataSet: X_data = (103, 9) , Y_data = (103, 1)

# %%
print("The Final Data For Preditcion is : {}".format(final_data_frame.shape))
# Out:
# The Final Data For Preditcion is : (1142, 9)

# %%
final_data_frame
# Out:
#          CID  MolecularWeight  HeavyAtomCount  XLogP  Complexity  \
# 0   54507330            503.6              36   -1.9       759.0
# 0   45486349            665.8              48   -0.7      1060.0
# 0   44457481            941.2              70    7.6      1580.0
# 0   24971364            574.7              41   -1.7       853.0
# 0   24971362            518.7              37   -1.5       724.0
# ..       ...              ...             ...    ...         ...
# 0    3993403            391.8              26    4.4       596.0
# 0    4249066            377.8              25    4.0       576.0
# 0    4292383            446.7              27    5.3       639.0
# 0    4337991            407.8              27    4.0       621.0
# 0    4381081            391.8              26    4.4       604.0
#
#     HBondAcceptorCount  MonoisotopicMass  RotatableBondCount   TPSA
# 0                    6        503.296851                  17  233.0
# 0                    7        665.412549                  20  271.0
# 0                    6        940.499967                  26  210.0
# 0                    7        574.370350                  21  259.0
# 0                    7        518.332902                  19  221.0
# ..                 ...               ...                 ...    ...
# 0                    6        391.039355                   5  113.0
# 0                    6        377.023705                   5  113.0
# 0                    6        444.945760                   5  113.0
# 0                    7        407.034269                   6  122.0
# 0                    6        391.039355                   5  113.0
#
# [1142 rows x 9 columns]

# %%
x_data = pd.DataFrame(x_data)
x_data.shape
# Out:
# (103, 9)

# %%
y_data = pd.DataFrame(y_data)
y_data.shape
# Out:
# (103, 1)

# %%
train_file = pd.DataFrame()
train_file
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
x_data = x_data.astype("float64")
y_data = y_data.astype("float64")

# %%
x_data.head()
# Out:
#           CID  MolecularWeight  HeavyAtomCount  XLogP  Complexity  \
# 0  24971348.0            608.8            44.0    0.5       884.0
# 0  24971347.0            532.7            38.0   -1.1       739.0
# 0  24971350.0            562.7            40.0   -1.1       793.0
# 0  24971362.0            518.7            37.0   -1.5       724.0
# 0  24971355.0            548.7            39.0   -1.0       757.0
#
#    HBondAcceptorCount  MonoisotopicMass  RotatableBondCount   TPSA
# 0                 7.0        608.379852                21.0  221.0
# 0                 7.0        532.348552                20.0  221.0
# 0                 8.0        562.359117                21.0  230.0
# 0                 7.0        518.332902                19.0  221.0
# 0                 8.0        548.343467                21.0  230.0

# %%
y_data.head()
# Out:
#           y
# 0  8.221849
# 1  8.045757
# 2  7.958607
# 3  7.886057
# 4  7.721246

# %%
new = y_data['y'].to_list()

# %%
train_file  = x_data
train_file['y'] = new

# %%
train_file
cid_reg_list=train_file['CID'].to_list()
train_file.drop('CID',axis=1,inplace =True)

# %%
train_file
# Out:
#     MolecularWeight  HeavyAtomCount  XLogP  Complexity  HBondAcceptorCount  \
# 0             608.8            44.0    0.5       884.0                 7.0
# 0             532.7            38.0   -1.1       739.0                 7.0
# 0             562.7            40.0   -1.1       793.0                 8.0
# 0             518.7            37.0   -1.5       724.0                 7.0
# 0             548.7            39.0   -1.0       757.0                 8.0
# ..              ...             ...    ...         ...                 ...
# 0             418.4            29.0    3.2       700.0                 9.0
# 0             358.4            26.0    3.5       424.0                 5.0
# 0             322.4            24.0    3.3       365.0                 3.0
# 0             320.4            24.0    3.5       400.0                 3.0
# 0             442.3            28.0    4.6       644.0                 7.0
#
#     MonoisotopicMass  RotatableBondCount   TPSA         y
# 0         608.379852                21.0  221.0  8.221849
# 0         532.348552                20.0  221.0  8.045757
# 0         562.359117                21.0  230.0  7.958607
# 0         518.332902                19.0  221.0  7.886057
# 0         548.343467                21.0  230.0  7.721246
# ..               ...                 ...    ...       ...
# 0         418.058320                 6.0  168.0  4.000000
# 0         358.149284                 6.0   47.3  4.000000
# 0         322.168128                 6.0   47.3  4.000000
# 0         320.152478                 6.0   44.1  4.000000
# 0         440.995297                 6.0  122.0  4.000000
#
# [103 rows x 9 columns]

# %%
for x in train_file.isnull().any():
    if x == True:
        train_file = train_file.fillna(method='ffill')

# %%
len(cid_reg_list)
# Out:
# 103

# %%
train_file['y']
# Out:
# 0    8.221849
# 0    8.045757
# 0    7.958607
# 0    7.886057
# 0    7.721246
#        ...
# 0    4.000000
# 0    4.000000
# 0    4.000000
# 0    4.000000
# 0    4.000000
# Name: y, Length: 103, dtype: float64

# %%
x = list(train_file.columns)
x = x[:-1]

x_ = train_file[x].values
y_ = train_file['y'].values

# %%
train_file.describe()
# Out:
#        MolecularWeight  HeavyAtomCount       XLogP   Complexity  \
# count       103.000000      103.000000  103.000000   103.000000
# mean        507.324175       36.000000    1.801942   796.611650
# std         174.478669       12.415203    2.249792   369.903756
# min         203.200000       15.000000   -4.500000   273.000000
# 25%         371.900000       26.000000    0.400000   538.000000
# 50%         506.400000       36.000000    2.100000   733.000000
# 75%         597.750000       43.000000    3.600000   904.500000
# max        1228.400000       89.000000    6.300000  2390.000000
#
#        HBondAcceptorCount  MonoisotopicMass  RotatableBondCount        TPSA  \
# count          103.000000        103.000000          103.000000  103.000000
# mean             7.000000        506.924106           12.252427  180.056311
# std              2.305152        174.362513            7.099735   84.541814
# min              2.000000        203.080710            2.000000   27.000000
# 25%              5.500000        371.611263            6.000000  122.000000
# 50%              7.000000        505.008839           10.000000  172.000000
# 75%              9.000000        597.340727           19.000000  259.000000
# max             15.000000       1227.632832           24.000000  380.000000
#
#                 y
# count  103.000000
# mean     5.674346
# std      1.100950
# min      4.000000
# 25%      4.904890
# 50%      5.627088
# 75%      6.105562
# max      8.221849

# %%
x_ = x_.astype("float64")
y_ = y_.astype("float64")

# %%
y_.shape
# Out:
# (103,)

# %%
x_.shape
# Out:
# (103, 8)

# %%
X_train, X_test, y_train, y_test = train_test_split(x_, y_, test_size=0.1, random_state=0)

# %%
print("Regression Starts")
# Out:
# Regression Starts

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
coef_dict = dict(zip(x, regressor.coef_))

y_pred = regressor.predict(X_test)

# %%
main_r2 = r2_score(y_test, y_pred, multioutput='uniform_average')
max_ = main_r2 



from itertools import combinations
comb_list = [[]]


def sub(arr,r):
    global comb_list
    for i in r:
        comb = list(combinations(arr,i))
        comb_list.append(comb)
    return comb_list

# %%
newone =0

newone = sub(x , [2,3,4,5,6])
del newone[0]

#index_count = 0
coef_dict  = 0
loop_index = 0
coef_dict = [[]]
r2_score_new =[]
max_r2 = []
index_r2 =[]

# %%
for i in range(0,len(newone)):
    
    index_r=0
    for combi_ in newone[loop_index]:
        
        #print(combi_)
        features = list(combi_)
        features_=train_file[features].values
        output_=train_file['y'].values
        X_train, X_test, y_train, y_test = train_test_split(features_, output_, test_size=0.1, random_state=0)
        regressor = LinearRegression()  
        regressor.fit(X_train, y_train)
        y_pred = regressor.predict(X_test)
        r2_score_  = r2_score(y_test, y_pred, multioutput='uniform_average')
        r2_score_new.append(r2_score_)
    loop_index+=1
        
    
    max_r2.append(max(r2_score_new))
    index_r = r2_score_new.index(max(r2_score_new))
    index_r2.append(index_r)
    r2_score_new =[]

# %%
sec_index = max_r2.index(max(max_r2))

# %%
#max_r2

# %%
fir_index = index_r2[sec_index]

# %%
if main_r2 > max(max_r2):
    r2_features = x
else:
    
    features  = newone[sec_index][fir_index]
maxi_r2 = max(max_r2)

# %%
#features

# %%
reg_max_r2 = max(max_r2)
#reg_max_r2

# %% [markdown]
# New Regression Part Starts [processing the best output to print out values/]

# %%
#train_file

# %%
for x in train_file.isnull().any():
    if x == True:
        train_file = train_file.fillna(method='ffill')

# %%
#train_file

# %%
features  = list(features)

# %%
x_trained =train_file[features].values

# %%
x_trained.shape
# Out:
# (103, 3)

# %%
y_trained = train_file['y'].values

# %%
y_trained.shape
# Out:
# (103,)

# %%
X_train, X_test, y_train, y_test = train_test_split(x_trained, y_trained, test_size=0.1, random_state=0)

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
coef_dict = dict(zip(features, regressor.coef_))
coef_dict = pd.DataFrame(coef_dict , index = [0])

# %%
y_pred = regressor.predict(X_test)

# %%
r2_score(y_test, y_pred, multioutput='uniform_average')
# Out:
# 0.8142140297418247

# %%
features
# Out:
# ['Complexity', 'MonoisotopicMass', 'RotatableBondCount']

# %%
saved_features = features

# %%
coef_dict

final_data_frame
# Out:
#          CID  MolecularWeight  HeavyAtomCount  XLogP  Complexity  \
# 0   54507330            503.6              36   -1.9       759.0
# 0   45486349            665.8              48   -0.7      1060.0
# 0   44457481            941.2              70    7.6      1580.0
# 0   24971364            574.7              41   -1.7       853.0
# 0   24971362            518.7              37   -1.5       724.0
# ..       ...              ...             ...    ...         ...
# 0    3993403            391.8              26    4.4       596.0
# 0    4249066            377.8              25    4.0       576.0
# 0    4292383            446.7              27    5.3       639.0
# 0    4337991            407.8              27    4.0       621.0
# 0    4381081            391.8              26    4.4       604.0
#
#     HBondAcceptorCount  MonoisotopicMass  RotatableBondCount   TPSA
# 0                    6        503.296851                  17  233.0
# 0                    7        665.412549                  20  271.0
# 0                    6        940.499967                  26  210.0
# 0                    7        574.370350                  21  259.0
# 0                    7        518.332902                  19  221.0
# ..                 ...               ...                 ...    ...
# 0                    6        391.039355                   5  113.0
# 0                    6        377.023705                   5  113.0
# 0                    6        444.945760                   5  113.0
# 0                    7        407.034269                   6  122.0
# 0                    6        391.039355                   5  113.0
#
# [1142 rows x 9 columns]

# %%
final_data_frame

final_data_frameF1 = final_data_frame[final_data_frame['MolecularWeight'] <= 500]
final_data_frameF2 = final_data_frameF1[final_data_frameF1['XLogP'] <=5.6]

final_data_frameF2
# Out:
#          CID  MolecularWeight  HeavyAtomCount  XLogP  Complexity  \
# 0     122267           416.50              30   -0.1       602.0
# 0     122185           320.39              23   -2.0       416.0
# 0    5287925           402.50              29   -0.6       587.0
# 0   71463275           438.50              32    0.4       638.0
# 0   71452593           438.50              32    0.4       638.0
# ..       ...              ...             ...    ...         ...
# 0    3993403           391.80              26    4.4       596.0
# 0    4249066           377.80              25    4.0       576.0
# 0    4292383           446.70              27    5.3       639.0
# 0    4337991           407.80              27    4.0       621.0
# 0    4381081           391.80              26    4.4       604.0
#
#     HBondAcceptorCount  MonoisotopicMass  RotatableBondCount   TPSA
# 0                    5        416.253589                  11  143.0
# 0                    4        320.196074                   9  163.0
# 0                    5        402.237939                  10  157.0
# 0                    4        438.237939                  12  166.0
# 0                    4        438.237939                  12  166.0
# ..                 ...               ...                 ...    ...
# 0                    6        391.039355                   5  113.0
# 0                    6        377.023705                   5  113.0
# 0                    6        444.945760                   5  113.0
# 0                    7        407.034269                   6  122.0
# 0                    6        391.039355                   5  113.0
#
# [712 rows x 9 columns]

# %%
pred_data_cid = final_data_frameF2["CID"].to_list()

# %%
features.append('CID')

# %%
new_features = features.append("CID")
features
# Out:
# ['Complexity', 'MonoisotopicMass', 'RotatableBondCount', 'CID', 'CID']

# %%
final_data_frame1 = final_data_frameF2[features]

# %%
final_data_frame1
# Out:
#     Complexity  MonoisotopicMass  RotatableBondCount       CID       CID
# 0        602.0        416.253589                  11    122267    122267
# 0        416.0        320.196074                   9    122185    122185
# 0        587.0        402.237939                  10   5287925   5287925
# 0        638.0        438.237939                  12  71463275  71463275
# 0        638.0        438.237939                  12  71452593  71452593
# ..         ...               ...                 ...       ...       ...
# 0        596.0        391.039355                   5   3993403   3993403
# 0        576.0        377.023705                   5   4249066   4249066
# 0        639.0        444.945760                   5   4292383   4292383
# 0        621.0        407.034269                   6   4337991   4337991
# 0        604.0        391.039355                   5   4381081   4381081
#
# [712 rows x 5 columns]

# %%
final_data_frame1.shape
# Out:
# (712, 5)

# %%
for x in final_data_frame1.isnull().any():
    if x == True:
        final_data_frame1 = final_data_frame1.fillna(method='ffill')

# %%
final_data_frame1.drop(columns='CID',inplace=True)
# Out:
# /home/ben/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
final_data_frame1
# Out:
#     Complexity  MonoisotopicMass  RotatableBondCount
# 0        602.0        416.253589                  11
# 0        416.0        320.196074                   9
# 0        587.0        402.237939                  10
# 0        638.0        438.237939                  12
# 0        638.0        438.237939                  12
# ..         ...               ...                 ...
# 0        596.0        391.039355                   5
# 0        576.0        377.023705                   5
# 0        639.0        444.945760                   5
# 0        621.0        407.034269                   6
# 0        604.0        391.039355                   5
#
# [712 rows x 3 columns]

# %%
final_pred = regressor.predict(final_data_frame1)

# %%
final_pred = list(final_pred)

# %%
final_data_frame1['CID'] = pred_data_cid
# Out:
# /home/ben/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
final_data_frame1['y_'] = final_pred
# Out:
# /home/ben/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
final_data_frame1
# Out:
#     Complexity  MonoisotopicMass  RotatableBondCount       CID        y_
# 0        602.0        416.253589                  11    122267  5.660625
# 0        416.0        320.196074                   9    122185  5.516415
# 0        587.0        402.237939                  10   5287925  5.513710
# 0        638.0        438.237939                  12  71463275  5.782076
# 0        638.0        438.237939                  12  71452593  5.782076
# ..         ...               ...                 ...       ...       ...
# 0        596.0        391.039355                   5   3993403  4.798215
# 0        576.0        377.023705                   5   4249066  4.793687
# 0        639.0        444.945760                   5   4292383  4.914412
# 0        621.0        407.034269                   6   4337991  4.924874
# 0        604.0        391.039355                   5   4381081  4.774919
#
# [712 rows x 5 columns]

# %%
saved_final_data_frame1 = final_data_frame1

# %%
sorted_final_df = final_data_frame1.sort_values('y_',ascending =0)

# %%
final_larg= sorted_final_df.head(30)

# %%
final_larg
# Out:
#    Complexity  MonoisotopicMass  RotatableBondCount        CID        y_
# 0       725.0        498.327816                  19  118717695  6.692631
# 0       554.0        430.301602                  17     448139  6.630275
# 0       554.0        430.301602                  17   11270374  6.630275
# 0       650.0        490.315520                  17   44367214  6.619490
# 0       648.0        458.307750                  17   52940699  6.481973
# 0       648.0        458.307750                  17    9890369  6.481973
# 0       681.0        488.347489                  16   54767073  6.392579
# 0       609.0        430.265216                  16  139036265  6.342128
# 0       743.0        486.313898                  17    4631411  6.330759
# 0       743.0        486.313898                  17     439610  6.330759
# 0       617.0        461.288971                  15   53230012  6.329939
# 0       617.0        461.288971                  15    9868928  6.329939
# 0       644.0        475.304621                  15     462382  6.314083
# 0       644.0        475.304621                  15   45103781  6.314083
# 0       644.0        475.304621                  15   44367242  6.314083
# 0       723.0        492.280866                  16  118714504  6.287892
# 0       580.0        416.249566                  15     129859  6.235980
# 0       608.0        478.330777                  13   71185698  6.176811
# 0       675.0        462.270302                  15  118714507  6.165441
# 0       630.0        461.288971                  14   10253763  6.164257
# 0       705.0        476.285952                  15  118714506  6.140849
# 0       715.0        477.281201                  15   21149982  6.116187
# 0       673.0        443.260465                  15  134350166  6.086133
# 0       746.0        490.301602                  15  118714518  6.084226
# 0       559.0        419.242021                  13     489994  6.054877
# 0       543.0        405.237604                  13   44283481  6.038752
# 0       672.0        460.279804                  14   10411941  6.037435
# 0       434.0        362.220557                  12       2532  6.035682
# 0       434.0        362.220557                  12      73364  6.035682
# 0       434.0        362.220557                  12   44366975  6.035682

# %%
final_larg = final_larg[['CID','y_']]

# %%
top_cid = final_larg["CID"].to_list()

# %%
for i in range(0,2):
    try:
        os.remove('downloaded1.csv')
        print("Deleted old File")
        break
    except Exception as e:
        print("No file ")
        break
    else:
        break
for i in range(0,2):
    try:
        os.remove('fdf1.csv')
        print("Deleted old File")
        break
    except Exception as e:
        print("No file ")
        break
    else:
        break
# Out:
# Deleted old File
# Deleted old File

# %%
print("The Top 30 Drug Leads Which are identified with PubChem cid's are: ")
itter_count = 0
for itter in top_cid:
    itter_count+=1
    
    print(str(itter_count)+" : "+str(itter))
# Out:
# The Top 30 Drug Leads Which are identified with PubChem cid's are:
# 1 : 118717695
# 2 : 448139
# 3 : 11270374
# 4 : 44367214
# 5 : 52940699
# 6 : 9890369
# 7 : 54767073
# 8 : 139036265
# 9 : 4631411
# 10 : 439610
# 11 : 53230012
# 12 : 9868928
# 13 : 462382
# 14 : 45103781
# 15 : 44367242
# 16 : 118714504
# 17 : 129859
# 18 : 71185698
# 19 : 118714507
# 20 : 10253763
# 21 : 118714506
# 22 : 21149982
# 23 : 134350166
# 24 : 118714518
# 25 : 489994
# 26 : 44283481
# 27 : 10411941
# 28 : 2532
# 29 : 73364
# 30 : 44366975

# %%
print("r2 = "+str(r2_score(y_test, y_pred, multioutput='uniform_average')))
# Out:
# r2 = 0.8142140297418247

# %%
print("Intercept = "+str(regressor.intercept_))
# Out:
# Intercept = 4.143394527523481

# %%
print("coefficients are :- ")
# Out:
# coefficients are :-

# %%
print(coef_dict)
# Out:
#    Complexity  MonoisotopicMass  RotatableBondCount
# 0   -0.002912          0.004478            0.127827

# %%
import urllib.request
from os.path import expanduser
import os
home = expanduser("~")
assert (os.path.isdir(home+'/MGLTools-1.5.6')), "AutoDockTools not found!"
#set preparation pathways
prepare_protein_path = '~/MGLTools-1.5.6/bin/pythonsh ~/MGLTools-1.5.6/MGLToolsPckgs/AutoDockTools/Utilities24/prepare_receptor4.py -A bonds_hydrogens -U nphs_lps_waters_nonstdres -r'
prepare_ligand_path = '~/MGLTools-1.5.6/bin/pythonsh ~/MGLTools-1.5.6/MGLToolsPckgs/AutoDockTools/Utilities24/prepare_ligand4.py -A bonds_hydrogens -U nphs_lps -l'


l=[]
for itter in top_cid:
    l.append(itter)
for i in l:


# download SDF


    url = 'https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/{}/SDF'.format(str(i))
    urllib.request.urlretrieve(url, '{}'.format(str(i)+'.sdf'))
    
    
#     prepare ligand by converting to mol2 followed by conversion to pdbqt
    print("Preparing ligand {} for docking".format(i))
    os.system('obabel {} -O {} --gen3d'.format(str(i)+'.sdf', str(i)+'.mol2'))
    os.system(prepare_ligand_path + '{}'.format(str(i)+'.mol2'))
    
    
    print("Running docking procedure for 2oy0")
    
    os.system(
    'vina --config coordinatesandsetups2oy0.txt --receptor 2oy0.pdbqt --ligand {} --out {} --log {}'.format(
    str(i)+'.pdbqt', str(i)+'.2oy0.pdbqt', str(i)+'.2oy0.log')
)
    print("Docking to 2oy0 protein completed. Files saved as {} as docked complex and {} as a logfile".format(
        str(i)+'.2oy0.pdbqt',str(i)+'.2oy0.log'))
    
    
    
    print("Running docking procedure for 1L9K")
    
    os.system(
    'vina --config coordinatesandsetups1l9k.txt --receptor 1L9K.pdbqt --ligand {} --out {} --log {}'.format(
    str(i)+'.pdbqt', str(i)+'.1L9K.pdbqt', str(i)+'.1L9K.log')
    )
    print("Docking to 1L9K protein completed. Files saved as {} as docked complex and {} as a logfile".format(
        str(i)+'.1L9K.pdbqt',str(i)+'.1L9K.log'))
    
    
    
    print(url)
    
    
    input("Press any key to continue In Silico modelling for next lead compound")
# Out:
# Preparing ligand 118717695 for docking
# Running docking procedure for 2oy0
# Docking to 2oy0 protein completed. Files saved as 118717695.2oy0.pdbqt as docked complex and 118717695.2oy0.log as a logfile
# Running docking procedure for 1L9K
# Docking to 1L9K protein completed. Files saved as 118717695.1L9K.pdbqt as docked complex and 118717695.1L9K.log as a logfile
# https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/118717695/SDF
